# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path='ObesityDataSet_raw_and_data_sinthetic.csv'
obesidad = pd.read_csv(path)
#print(obesidad.info())
print(obesidad)
#obesidad.describe()
#obesidad.groupby("Gender").count()
#obesidad.groupby(["Gender", "family_history_with_overweight"]).count()

#obesidad.groupby('Gender').first()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
#      FAVC  FCVC  NCP       CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# 0      no   2.0  3.0  Sometimes    no  2.000000   no  0.000000  1.000000
# 1      no   3.0  3.0  Sometimes   yes  3.000000  yes  3.000000  0.000000
# 2      no   2.0  3.0  Sometimes    no  2.000000   no  2.000000  1.000000
# 3      no   3.0  3.0  Sometimes    no  2.000000   no  2.000000  0.000000
# 4      no   2.0  1.0  Sometimes    no  2.000000   no  0.000000  0.000000
# ...   ...   ...  ...        ...   ...       ...  ...       ...       ...
# 2106  yes   3.0  3.0  Sometimes    no  1.728139   no  1.676269  0.906247
# 2107  yes   3.0  3.0  Sometimes    no  2.005130   no  1.341390  0.599270
# 2108  yes   3.0  3.0  Sometimes    no  2.054193   no  1.414209  0.646288
# 2109  yes   3.0  3.0  Sometimes    no  2.852339   no  1.139107  0.586035
# 2110  yes   3.0  3.0  Sometimes    no  2.863513   no  1.026452  0.714137
#
#             CALC                 MTRANS           NObeyesdad
# 0             no  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 2     Frequently  Public_Transportation        Normal_Weight
# 3     Frequently                Walking   Overweight_Level_I
# 4      Sometimes  Public_Transportation  Overweight_Level_II
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [2111 rows x 17 columns]

# %%
#obesidad.groupby(["Gender", "family_history_with_overweight", "FAVC", "CAEC", "SMOKE", "SCC"]).size()

#obesidad.groupby(["Gender", "Weight"]).mean() 1043 - 1068
#obesidad.groupby(["Gender"]).mean()
#obesidad.groupby(["Gender"])[["Weight"]].agg({'text':'Weight', 'sent':'mean'})

ob = obesidad.groupby(["Gender", "family_history_with_overweight"]).agg( Cantidad=('Gender', 'count'),Promedio=('Weight', 'mean'),F=('family_history_with_overweight', groups))
ob['Porcentaje(%)'] = (ob['Cantidad'] / 
                  ob['Cantidad'].groupby("Gender").sum()) * 100
ob
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [112], in <cell line: 7>()
#       1 #obesidad.groupby(["Gender", "family_history_with_overweight", "FAVC", "CAEC", "SMOKE", "SCC"]).size()
#       2
#       3 #obesidad.groupby(["Gender", "Weight"]).mean() 1043 - 1068
#       4 #obesidad.groupby(["Gender"]).mean()
#       5 #obesidad.groupby(["Gender"])[["Weight"]].agg({'text':'Weight', 'sent':'mean'})
# ----> 7 ob = obesidad.groupby(["Gender", "family_history_with_overweight"]).agg( Cantidad=('Gender', 'count'),Promedio=('Weight', 'mean'),F=('family_history_with_overweight', groups))
#       8 ob['Porcentaje(%)'] = (ob['Cantidad'] /
#       9                   ob['Cantidad'].groupby("Gender").sum()) * 100
#      10 ob
#
# NameError: name 'groups' is not defined

# %%
#Histograma del atributo clase
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot(x='Gender',data=obesidad)
plt.title("Gender count")
plt.show()

# %%
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot(x='family_history_with_overweight',data=obesidad)
plt.title("family_history_with_overweight count")
plt.show()

# %%
ax=plt.subplots(1,1,figsize=(10,8))
sns.countplot(x='FAVC',data=obesidad)
plt.title("FAVC")
plt.show()

# %%
obesidad.hist(edgecolor='black', linewidth=1.0)
fig=plt.gcf()
fig.set_size_inches(20,20)
plt.show()

# %%
X = obesidad.iloc[:, 0:17]
f, ax = plt.subplots(figsize=(10, 8))
corr = X.corr()
print(corr)
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=bool), 
          cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax, linewidths=.5)
plt.show()
# Out:
#              Age    Height    Weight      FCVC       NCP      CH2O       FAF  \
# Age     1.000000 -0.025958  0.202560  0.016291 -0.043944 -0.045304 -0.144938
# Height -0.025958  1.000000  0.463136 -0.038121  0.243672  0.213376  0.294709
# Weight  0.202560  0.463136  1.000000  0.216125  0.107469  0.200575 -0.051436
# FCVC    0.016291 -0.038121  0.216125  1.000000  0.042216  0.068461  0.019939
# NCP    -0.043944  0.243672  0.107469  0.042216  1.000000  0.057088  0.129504
# CH2O   -0.045304  0.213376  0.200575  0.068461  0.057088  1.000000  0.167236
# FAF    -0.144938  0.294709 -0.051436  0.019939  0.129504  0.167236  1.000000
# TUE    -0.296931  0.051912 -0.071561 -0.101135  0.036326  0.011965  0.058562
#
#              TUE
# Age    -0.296931
# Height  0.051912
# Weight -0.071561
# FCVC   -0.101135
# NCP     0.036326
# CH2O    0.011965
# FAF     0.058562
# TUE     1.000000

# %%
#obesidad = obesidad.drop('#',axis=1)
box_data = obesidad.Age #variable representing the data array
#print(box_data.head())
box_target = obesidad.Age #variable representing the labels array
sns.boxplot(data = box_data,width=0.5,fliersize=5)
#sns.set(rc={'figure.figsize':(2,15)})
plt.show()

# %%
#obesidad = obesidad.drop('#',axis=1)
box_data = obesidad.FAF #variable representing the data array
#print(box_data.head())
box_target = obesidad.FAF #variable representing the labels array
sns.boxplot(data = box_data,width=0.5,fliersize=5)
#sns.set(rc={'figure.figsize':(2,15)})
plt.show()
